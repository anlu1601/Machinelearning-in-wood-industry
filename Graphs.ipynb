# %%
import timeit
import matplotlib.pyplot as plt
import os
import time
import numpy as np
import cv2
import csv
from google.colab import drive
drive.mount('/content/drive')

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Hparam graphs IMG CLASS

# %% [markdown]
# ### ZFnet hparams

# %%
X = ['0.5', '0.6', '0.7', '0.8', '0.9']
scale_factor = 0.8

sgd = [0.97512, 0.97674, 0.96204, 0, 0]
adam = [0.93091, 0.89321, 0.81905, 0.87139, 0.94238]
sgd = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd]
adam = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, sgd, 0.4, scale_factor, label = 'SGD')
plt.bar(X_axis + 0.2, adam, 0.4, scale_factor, label = 'Adam')

plt.annotate(sgd[1]+scale_factor, (1, sgd[1]+scale_factor))
  
plt.xticks(X_axis, X)
plt.xlabel("Dropout")
plt.ylabel("F1 Score")
plt.title("F1 Score - 50 Epochs - 80%+")
plt.legend()
#plt.savefig('F1scoreCV50ZF.png', bbox_inches='tight')
plt.show()

# %%
X = ['0.5', '0.6', '0.7', '0.8', '0.9']
scale_factor = 0.6

sgd = [0.78669, 0.8814, 0.63409, 0, 0]
adam = [0.73635, 0.67391, 0.61591, 0.38676, 0.65879]
sgd = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd]
adam = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, sgd, 0.4, scale_factor, label = 'SGD')
plt.bar(X_axis + 0.2, adam, 0.4, scale_factor, label = 'Adam')


plt.annotate(sgd[1]+scale_factor, (1, sgd[1]+scale_factor))
  

plt.xticks(X_axis, X)
plt.xlabel("Dropout")
plt.ylabel("F1 Score")
plt.title("F1 Score - 30 Epochs - 60%+")
plt.legend()
#plt.savefig('F1scoreCV30ZF.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Densenet hparams

# %%
X = ['None', 'Imagenet']
scale_factor = 0.5

sgd = [0.69405, 1]
adam = [0.73346, 0.61226]
sgd = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd]
adam = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, sgd, 0.4, scale_factor, label = 'SGD')
plt.bar(X_axis + 0.2, adam, 0.4, scale_factor, label = 'Adam')

plt.annotate(sgd[1]+scale_factor, (1, sgd[1]+scale_factor))
  
plt.xticks(X_axis, X)
plt.xlabel("Transfer learning")
plt.ylabel("F1 Score")
plt.title("F1 Score - 50 Epochs - 50%+")
plt.legend(loc='center right')
#plt.savefig('F1scoreCV50Dense.png', bbox_inches='tight')
plt.show()

# %%
X = ['None', 'Imagenet']
scale_factor = 0.5			

sgd = [0.9746, 1]
adam = [0.61534, 0.58851]
sgd = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd]
adam = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam]

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, sgd, 0.4, scale_factor, label = 'SGD')
plt.bar(X_axis + 0.2, adam, 0.4, scale_factor, label = 'Adam')

plt.annotate(sgd[1]+scale_factor, (1, sgd[1]+scale_factor))
  
plt.xticks(X_axis, X)
plt.xlabel("Transfer learning")
plt.ylabel("F1 Score")
plt.title("F1 Score - 30 Epochs - 50%+")
plt.legend(loc='center right')
#plt.savefig('F1scoreCV30Dense.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Outlier hparams

# %%
X = ['relu', 'tanh', 'swish']
scale_factor = 0.6


#sgd = [0.70099, 0.70639, 0.73051]
#adam = [0.63049, 0.78356, 0.6879]

sgd_all = [[0.70099, 0.70639, 0.73051], [0.7107, 0.67648, 0.72466], [0.67724, 0.71546, 0.70843], [0.70418, 0.71255, 0]]
adam_all = [[0.63049, 0.78356, 0.6879], [0.63787, 0.66156, 0.60625], [0.7144, 0.70948, 0.54694], [0.66332, 0.67966, 0.58235]]

#sgd = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd]
#adam = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam]

sgd_30 = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd_all[0]]
adam_30 = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam_all[0]]

sgd_50 = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd_all[1]]
adam_50 = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam_all[1]]

sgd_70 = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd_all[2]]
adam_70 = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam_all[2]]

sgd_100 = [s - scale_factor if s - scale_factor > 0 else 0 for s in sgd_all[3]]
adam_100 = [s - scale_factor if s - scale_factor > 0 else 0 for s in adam_all[3]]

sgd_all = [sgd_30, sgd_50, sgd_70, sgd_100]
adam_all = [adam_30, adam_50, adam_70, adam_100]

X_axis = np.arange(len(X))
  
sgd = np.mean(sgd_all, axis=0)
adam = np.mean(adam_all, axis=0)

plt.bar(X_axis - 0.2, sgd, 0.4, scale_factor, label = 'SGD')
plt.bar(X_axis + 0.2, adam, 0.4, scale_factor, label = 'Adam')

plt.annotate(adam[1]+scale_factor, (1.4, adam[1]+scale_factor))
  
plt.xticks(X_axis, X)
plt.xlabel("Activation function")
plt.ylabel("F1 Score")
plt.title("F1 Score - Average over 30,50,70,100 Epochs - 60%+")
plt.legend(loc='lower left')
#plt.savefig('F1scoreCV50ZF.png', bbox_inches='tight')
plt.show()

# %%
X = ['0.01', '0.1', '0.15', '0.2', '0.25' , '0.3', '0.4']
scale_factor = 0.6


f1 = [0.7354664926,
      0.8065630199,
      0.8168784602,
      0.8249909566,
      0.831013507,
      0.7956463007,
      0.7443671431]

f1 = [s - scale_factor if s - scale_factor > 0 else 0 for s in f1]

X_axis = np.arange(len(X))

plt.bar(X_axis, f1, 0.5, scale_factor, label = 'F1')

plt.annotate(f1[4]+scale_factor, (4.3, f1[4]+scale_factor))
  
plt.xticks(X_axis, X)
plt.xlabel("NU parameter")
plt.ylabel("F1 Score")
plt.title("F1 Score - 100 Epochs - SVM tuning - 60%+")
plt.legend(loc='lower left')
#plt.savefig('F1scoreCV50ZF.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### DenseNet

# %%
f1 = []
acc = []
valacc = []
loss = []
valloss = []
with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/f1_score.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        f1 = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/acc.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        acc = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/valacc.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        valacc = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/loss.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        loss = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/valloss.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        valloss = row
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-55593357c525> in <module>
#       4 loss = []
#       5 valloss = []
# ----> 6 with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/f1_score.csv") as csvfile:
#       7     reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
#       8     for row in reader: # each row is a list
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Masterthesis/csv_files/densenet/f1_score.csv'

# %%
f1

# %%
print(np.mean(f1))

# %%
f,ax=plt.subplots(1,1,figsize=(10,5));


ax.plot(acc, label='Train accuracy mean');

ax.plot(valacc, label='Validation accuracy mean');


ax.set_xlabel('Epochs')
ax.set_ylabel('Accuracy')
ax.set_title('DenseNet model Accuracy average over 10 Kfolds')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend(loc='upper right');

# %%
f,ax=plt.subplots(1,1,figsize=(10,5))

ax.plot(loss, label='Train loss mean')

ax.plot(valloss, label='Validation loss mean')

ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.set_title('DenseNet model Loss average over 10 Kfolds')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend();

# %% [markdown]
# ### DenseNet On Test data

# %%
#f1_scores, mccs, y_true, y_predicted_probs, y_predicted_labels
f1_scores = []
mccs = []
y_true = []
y_predicted_probs = []
y_predicted_labels = []
times_gpu = []
times_cpu = []

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/f1_score_testdata") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        f1_scores = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/mcc_test") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        mccs = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/y_true.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_true = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/y_prob.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_predicted_probs = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/y_pred.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_predicted_labels = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/time.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        times_gpu = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/densenet/time_cpu.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        times_cpu = row

# %%
#y_true = [int(i) for i in y_true]
#y_predicted_labels = [int(i) for i in y_predicted_labels]

# %%
precision, recall, _ = precision_recall_curve(y_true, y_predicted_labels)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %%
auc(recall, precision)
# Out:
# 1.0

# %%
average_precision_score(y_true, y_predicted_labels)
# Out:
# 1.0

# %%
print(f1_scores)
print(np.mean(f1_scores))
print(np.max(f1_scores))
print(np.min(f1_scores))
print(np.std(f1_scores))

# %%
print(mccs)
print(np.mean(mccs))
print(np.max(mccs))
print(np.min(mccs))
print(np.std(mccs))

# %%
cm = confusion_matrix(y_true, y_predicted_labels)

labels = ["Good data", "Fault data"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
#print(times)
print(np.mean(times_gpu))
print(np.max(times_gpu))
print(np.min(times_gpu))
print(np.std(times_gpu))

# %%
#print(times)
print(np.mean(times_cpu))
print(np.max(times_cpu))
print(np.min(times_cpu))
print(np.std(times_cpu))

# %% [markdown]
# ### ZFnet Crossvalidation graphs

# %%
f1 = []
acc = []
valacc = []
loss = []
valloss = []
with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/f1_score.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        f1 = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/acc.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        acc = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/valacc.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        valacc = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/loss.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        loss = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/valloss.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        valloss = row

# %%
f,ax=plt.subplots(1,1,figsize=(10,5));


ax.plot(acc, label='Train accuracy mean');

ax.plot(valacc, label='Validation accuracy mean');


ax.set_xlabel('Epochs')
ax.set_ylabel('Accuracy')
ax.set_title('ZFnet model Accuracy average over 10 Kfolds')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend(loc='upper right');

# %%
f,ax=plt.subplots(1,1,figsize=(10,5))

ax.plot(loss, label='Train loss mean')

ax.plot(valloss, label='Validation loss mean')

ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.set_title('ZFnet model Loss average over 10 Kfolds')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend();

# %% [markdown]
# ### ZFnet On Test data

# %%
#f1_scores, mccs, y_true, y_predicted_probs, y_predicted_labels
f1_scores = []
mccs = []
y_true = []
y_predicted_probs = []
y_predicted_labels = []
times_gpu = []
times_cpu = []

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/f1_score_testdata") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        f1_scores = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/mcc_test") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        mccs = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/y_true.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_true = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/y_prob.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_predicted_probs = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/y_pred.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_predicted_labels = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/time.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        times_gpu = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/zfnet/time_cpu.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        times_cpu = row

# %%
#y_true = [int(i) for i in y_true]
#y_predicted_labels = [int(i) for i in y_predicted_labels]

# %%
precision, recall, _ = precision_recall_curve(y_true, y_predicted_labels)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %%
auc(recall, precision)
# Out:
# 0.9782296650717703

# %%
average_precision_score(y_true, y_predicted_labels)
# Out:
# 0.9564593301435407

# %%
print(f1_scores)
print(np.mean(f1_scores))
print(np.max(f1_scores))
print(np.min(f1_scores))
print(np.std(f1_scores))
# Out:
# [0.8823529411764706, 1.0, 1.0, 0.9444444444444444, 0.972972972972973, 0.9444444444444444, 1.0, 0.972972972972973, 0.972972972972973, 1.0]
# 0.9690160748984278
# 1.0
# 0.8823529411764706
# 0.03550354120191457

# %%
print(mccs)
print(np.mean(mccs))
print(np.max(mccs))
print(np.min(mccs))
print(np.std(mccs))
# Out:
# [0.8696164022030687, 1.0, 1.0, 0.9356789992229548, 0.9680242446422006, 0.9356789992229548, 1.0, 0.9680242446422006, 0.9680242446422006, 1.0]
# 0.9645047134575581
# 1.0
# 0.8696164022030687
# 0.0396767664776228

# %%
cm = confusion_matrix(y_true, y_predicted_labels)

labels = ["Good data", "Fault data"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
#print(times)
print(np.mean(times_gpu))
print(np.max(times_gpu))
print(np.min(times_gpu))
print(np.std(times_gpu))
# Out:
# 0.008204214572906494
# 0.01210331916809082
# 0.007387876510620117
# 0.0008030876890333737

# %%
#print(times)
print(np.mean(times_cpu))
print(np.max(times_cpu))
print(np.min(times_cpu))
print(np.std(times_cpu))
# Out:
# 0.08865642070770263
# 0.11797547340393066
# 0.08289170265197754
# 0.005039039827557444

# %% [markdown]
# ### Outlier On Crossvalidation graphs

# %%
val_f1 = []
val_acc = []
loss = []
val_loss = []
mse = []
val_mse = []

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/val_f1.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        val_f1 = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/val_acc.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        val_acc = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/loss.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        loss = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/val_loss.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        val_loss = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/mse.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        mse = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/val_mse.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        val_mse = row

# %%
f,ax=plt.subplots(1,1,figsize=(10,5));

x_ticks = [i for i in range(301) if i % 10 == 0]



ax.plot(val_f1, label='Validation F1 score');

ax.plot(val_acc, label='Validation Accuracy');

#ax.set_xticks(x_ticks)

ticks = ax.get_xticks()*10
ax.set_xticklabels(ticks.astype(int))


ax.set_xlabel('Epochs')
ax.set_ylabel('Score')
ax.set_title('CAE with SVM model Accuracy and F1 score average over 10 Kfolds')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend(loc='upper right');

# %%
f,ax=plt.subplots(1,1,figsize=(10,5));


ax.plot(loss, label='Training loss');

ax.plot(val_loss, label='Validation loss');


ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.set_title('CAE model Loss average over 10 Kfolds')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend(loc='upper right');

# %%
f,ax=plt.subplots(1,1,figsize=(10,5));


ax.plot(mse, label='Training mse');

ax.plot(val_mse, label='Validation mse');


ax.set_xlabel('Epochs')
ax.set_ylabel('MSE')
ax.set_title('CAE model MSE average over 10 Kfolds')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend(loc='upper right');

# %% [markdown]
# ### Outlier On Test data

# %%
#f1_scores, mccs, y_true, y_predicted_probs, y_predicted_labels
f1_scores = []
mccs = []
y_true = []
y_predicted_labels = []
times_gpu = []
times_cpu = []
truemsenormal = []
truemseerror = []
predmsenormal = []
predmseerror = []

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/f1_score_testdata.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        f1_scores = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/mcc_test.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        mccs = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/y_true.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_true = row


with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/y_pred.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        y_predicted_labels = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/time.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        times_gpu = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/time_cpu.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        times_cpu = row


with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/truemsenormal.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        truemsenormal = row


with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/truemseerr.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        truemseerror = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/predmsenormal.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        predmsenormal = row

with open("/content/drive/MyDrive/Masterthesis/csv_files/cae/predmseerr.csv") as csvfile:
    reader = csv.reader(csvfile, quoting=csv.QUOTE_NONNUMERIC) # change contents to floats
    for row in reader: # each row is a list
        predmseerror = row

# %%
precision, recall, _ = precision_recall_curve(y_true, y_predicted_labels)
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.show()

# %%
average_precision_score(y_true, y_predicted_labels)
# Out:
# 0.9137894363700815

# %%
auc(recall, precision)
# Out:
# 0.9568947181850407

# %%
print(f1_scores)
print(np.mean(f1_scores))
print(np.max(f1_scores))
print(np.min(f1_scores))
print(np.std(f1_scores))
# Out:
# [0.8152866242038217, 0.8258064516129032, 0.8181818181818181, 0.8152866242038217, 0.8765432098765432, 0.8258064516129032, 0.8624999999999999, 0.8711656441717792, 0.8695652173913044, 0.830188679245283]
# 0.8410330720500179
# 0.8765432098765432
# 0.8152866242038217
# 0.024234466894148946

# %%
print(mccs)
print(np.mean(mccs))
print(np.max(mccs))
print(np.min(mccs))
print(np.std(mccs))
# Out:
# [0.6691803304987917, 0.7032967032967034, 0.6939779183594883, 0.6691803304987917, 0.7710078896365051, 0.7032967032967034, 0.751181027693032, 0.754808387735078, 0.7610423906471906, 0.6886071746900094]
# 0.7165578856352294
# 0.7710078896365051
# 0.6691803304987917
# 0.037064292167399995

# %%
cm = confusion_matrix(y_true, y_predicted_labels)

labels = ["Good data", "Fault data"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
f,ax=plt.subplots(1,1,figsize=(7,5));

x_ticks = [i for i in range(301) if i % 10 == 0]



ax.plot(predmsenormal, 'bo', label='Predicted normals');

ax.plot(predmseerror, 'r^', label='Predicted anomalies');



ax.set_ylabel('MSE')
ax.set_title('SVM model Predicted classes')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend(loc='upper right');

# %%
f,ax=plt.subplots(1,1,figsize=(7,5));


ax.plot(truemsenormal, 'bo', label='True normals');

ax.plot(truemseerror, 'r^', label='True anomalies');



ax.set_ylabel('MSE')
ax.set_title('CAE output True classes')

#ax[1].plot(np.mean(acc[0], axis=0), label='Validation accuracy mean')
f.legend(loc='upper right');

# %%
#print(times)
print(np.mean(times_gpu))
print(np.max(times_gpu))
print(np.min(times_gpu))
print(np.std(times_gpu))
# Out:
# 0.04503598928451538
# 0.09685754776000977
# 0.039144039154052734
# 0.008596693824132168

# %%
#print(times_cpu)
print(np.mean(times_cpu))
print(np.max(times_cpu))
print(np.min(times_cpu))
print(np.std(times_cpu))
# Out:
# 0.1621781611442566
# 0.3340282440185547
# 0.09585213661193848
# 0.05590458514423649
